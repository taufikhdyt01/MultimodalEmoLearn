# %% [markdown]
# # 🎯 Landmark Model Training - Optimized for AMD GPU
#
# Training model landmark untuk klasifikasi emosi menggunakan facial landmarks dengan optimasi GPU.

# %% [markdown]
# ## 1. 📚 Import Libraries

# %%
import numpy as np
import tensorflow as tf
import os
import time
import pickle
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. 🎮 AMD GPU Setup

# %%
def setup_amd_gpu():
    """Setup AMD GPU with DirectML for optimal performance"""
    print("🎮 Setting up AMD GPU for Landmark Training...")
    
    try:
        gpu_devices = tf.config.list_physical_devices('GPU')
        dml_devices = tf.config.list_physical_devices('DML')
        total_devices = len(gpu_devices) + len(dml_devices)
        
        if total_devices > 0:
            print(f"✅ Found {total_devices} GPU device(s)")
            
            # Configure GPU memory growth
            for gpu in gpu_devices:
                tf.config.experimental.set_memory_growth(gpu, True)
            print("✅ GPU memory growth enabled")
            
            # Enable XLA compilation
            tf.config.optimizer.set_jit(True)
            print("✅ XLA compilation enabled")
            
            return True, total_devices
        else:
            print("⚠️ No GPU detected, using CPU")
            return False, 0
    except Exception as e:
        print(f"⚠️ GPU setup failed: {e}")
        return False, 0

# Setup GPU
gpu_available, num_gpus = setup_amd_gpu()
# Out:
# 🎮 Setting up AMD GPU for Landmark Training...
# ✅ Found 2 GPU device(s)
# ✅ GPU memory growth enabled
# ✅ XLA compilation enabled

# %% [markdown]
# ## 3. ⚙️ Konfigurasi Training

# %%
# GPU-optimized configurations
if gpu_available:
    BATCH_SIZE = 256  # Larger batch for landmarks (smaller data)
    EPOCHS = 150      # More epochs for landmarks
else:
    BATCH_SIZE = 64
    EPOCHS = 80

# Paths
BASE_PATH = 'D:/research/2025_iris_taufik/MultimodalEmoLearn/data/'
MODEL_PATH = 'D:/research/2025_iris_taufik/MultimodalEmoLearn/models/'

print(f"🎯 Landmark Training Configuration:")
print(f"   Device: {'AMD GPU' if gpu_available else 'CPU'}")
print(f"   Batch Size: {BATCH_SIZE}")
print(f"   Max Epochs: {EPOCHS}")
# Out:
# 🎯 Landmark Training Configuration:
#    Device: AMD GPU
#    Batch Size: 256
#    Max Epochs: 150

# %% [markdown]
# ## 4. 📁 Load Data

# %%
print("📁 Loading landmark data...")

try:
    # Load landmark features
    X_train_landmarks = np.load(BASE_PATH + 'landmarks/X_train_landmarks.npy')
    X_val_landmarks = np.load(BASE_PATH + 'landmarks/X_val_landmarks.npy')
    X_test_landmarks = np.load(BASE_PATH + 'landmarks/X_test_landmarks.npy')
    
    # Load labels
    y_train = np.load(BASE_PATH + 'landmarks/y_train.npy')
    y_val = np.load(BASE_PATH + 'landmarks/y_val.npy')
    y_test = np.load(BASE_PATH + 'landmarks/y_test.npy')
    
    print(f"✅ Landmark data loaded successfully!")
    print(f"Training samples: {X_train_landmarks.shape[0]:,}")
    print(f"Validation samples: {X_val_landmarks.shape[0]:,}")
    print(f"Test samples: {X_test_landmarks.shape[0]:,}")
    print(f"Landmark features: {X_train_landmarks.shape[1]}")
    
except Exception as e:
    print(f"❌ Error loading data: {e}")
    exit(1)
# Out:
# 📁 Loading landmark data...
# ✅ Landmark data loaded successfully!
# Training samples: 784
# Validation samples: 98
# Test samples: 98
# Landmark features: 136

# %% [markdown]
# ## 5. 🏷️ Load Label Mapping

# %%
print("🏷️ Loading label mapping...")

try:
    with open(MODEL_PATH + 'label_map.pkl', 'rb') as f:
        label_map = pickle.load(f)
    
    num_classes = len(label_map)
    target_names = list(label_map.keys())
    
    print(f"Classes: {target_names}")
    print(f"Number of classes: {num_classes}")
    
except FileNotFoundError:
    print("❌ Label mapping not found! Please train CNN model first.")
    exit(1)

# Convert labels
y_train_num = np.array([label_map[label] for label in y_train])
y_val_num = np.array([label_map[label] for label in y_val])
y_test_num = np.array([label_map[label] for label in y_test])

# One-hot encoding
y_train_onehot = to_categorical(y_train_num, num_classes)
y_val_onehot = to_categorical(y_val_num, num_classes)
y_test_onehot = to_categorical(y_test_num, num_classes)

print("✅ Label preprocessing completed")
# Out:
# 🏷️ Loading label mapping...
# Classes: ['angry', 'contempt', 'disgusted', 'fear', 'happy', 'sad', 'surprised']
# Number of classes: 7
# ✅ Label preprocessing completed

# %% [markdown]
# ## 6. 🧠 Build Landmark Model

# %%
def build_optimized_landmark_model(input_dim, num_classes):
    """Build landmark model optimized for GPU training"""
    
    device_context = '/GPU:0' if gpu_available else '/CPU:0'
    
    with tf.device(device_context):
        model = Sequential([
            # Input layer
            Dense(512 if gpu_available else 256, activation='relu', input_dim=input_dim),
            BatchNormalization(),
            Dropout(0.3),
            
            # Hidden layers - more complex for GPU
            Dense(256 if gpu_available else 128, activation='relu'),
            BatchNormalization(),
            Dropout(0.4),
            
            Dense(128 if gpu_available else 64, activation='relu'),
            BatchNormalization(),
            Dropout(0.3),
            
            # Additional layer for GPU
            Dense(64, activation='relu') if gpu_available else Dense(32, activation='relu'),
            BatchNormalization(),
            Dropout(0.2),
            
            # Output layer
            Dense(num_classes, activation='softmax')
        ])
    
    # Compile with optimized learning rate
    learning_rate = 0.001 if gpu_available else 0.01
    
    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %% [markdown]
# ## 7. 🔧 Setup Callbacks

# %%
print("⚙️ Setting up callbacks...")

# Model checkpoint
checkpoint = ModelCheckpoint(
    MODEL_PATH + 'landmark_model_best.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

# Early stopping
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=20 if gpu_available else 15,
    restore_best_weights=True,
    verbose=1,
    mode='max'
)

# Learning rate reduction
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=10 if gpu_available else 7,
    min_lr=1e-7,
    verbose=1
)

callbacks = [checkpoint, early_stopping, reduce_lr]
# Out:
# ⚙️ Setting up callbacks...

# %% [markdown]
# ## 8. 🚀 Train Model

# %%
print(f"🚀 Training Landmark model on {'GPU' if gpu_available else 'CPU'}...")
print("=" * 60)

# Build model
landmark_model = build_optimized_landmark_model(X_train_landmarks.shape[1], num_classes)

print("📊 Model Summary:")
print(f"Total Parameters: {landmark_model.count_params():,}")
trainable_params = sum([tf.size(w).numpy() for w in landmark_model.trainable_weights])
print(f"Trainable Parameters: {trainable_params:,}")

# Training
start_time = time.time()

try:
    device_context = '/GPU:0' if gpu_available else '/CPU:0'
    
    with tf.device(device_context):
        landmark_history = landmark_model.fit(
            X_train_landmarks,
            y_train_onehot,
            batch_size=BATCH_SIZE,
            epochs=EPOCHS,
            validation_data=(X_val_landmarks, y_val_onehot),
            callbacks=callbacks,
            verbose=1
        )
    
    training_time = time.time() - start_time
    print(f"✅ Training completed in {training_time/3600:.2f} hours")
    
except Exception as e:
    print(f"❌ Training failed: {e}")
    if gpu_available and 'memory' in str(e).lower():
        print("💡 Retrying with smaller batch size...")
        BATCH_SIZE = 64
        landmark_history = landmark_model.fit(
            X_train_landmarks,
            y_train_onehot,
            batch_size=BATCH_SIZE,
            epochs=EPOCHS,
            validation_data=(X_val_landmarks, y_val_onehot),
            callbacks=callbacks,
            verbose=1
        )
# Out:
# 🚀 Training Landmark model on GPU...
# ============================================================
# 📊 Model Summary:
# Total Parameters: 246,919
# Trainable Parameters: 244,999
# Epoch 1/150
# 1/4 [======>.......................] - ETA: 2s - loss: 2.9113 - accuracy: 0.1289
# Epoch 1: val_accuracy improved from -inf to 0.25510, saving model to D:/research/2025_iris_taufik/MultimodalEmoLearn/models\landmark_model_best.h5
# 4/4 [==============================] - 1s 80ms/step - loss: 2.3816 - accuracy: 0.2283 - val_loss: 34.5476 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 2/150
# 1/4 [======>.......................] - ETA: 0s - loss: 1.4679 - accuracy: 0.4297
# Epoch 2: val_accuracy did not improve from 0.25510
# 4/4 [==============================] - 0s 14ms/step - loss: 1.3257 - accuracy: 0.5115 - val_loss: 45.9428 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 3/150
# 1/4 [======>.......................] - ETA: 0s - loss: 1.0631 - accuracy: 0.6328
# Epoch 3: val_accuracy did not improve from 0.25510
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0718 - accuracy: 0.6135 - val_loss: 45.8010 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 4/150
# 1/4 [======>.......................] - ETA: 0s - loss: 1.0169 - accuracy: 0.6016
# Epoch 4: val_accuracy did not improve from 0.25510
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9173 - accuracy: 0.6594 - val_loss: 41.6307 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 5/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7738 - accuracy: 0.7070
# Epoch 5: val_accuracy did not improve from 0.25510
# 4/4 [==============================] - 0s 15ms/step - loss: 0.8421 - accuracy: 0.6862 - val_loss: 41.5792 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 6/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.8838 - accuracy: 0.6797
# Epoch 6: val_accuracy did not improve from 0.25510
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8321 - accuracy: 0.7015 - val_loss: 39.1185 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 7/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7794 - accuracy: 0.7031
# Epoch 7: val_accuracy did not improve from 0.25510
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7291 - accuracy: 0.7207 - val_loss: 34.5597 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 8/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7237 - accuracy: 0.7227
# Epoch 8: val_accuracy did not improve from 0.25510
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7140 - accuracy: 0.7398 - val_loss: 28.2803 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 9/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6882 - accuracy: 0.7461
# Epoch 9: val_accuracy did not improve from 0.25510
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6892 - accuracy: 0.7500 - val_loss: 20.9253 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 10/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6441 - accuracy: 0.7734
# Epoch 10: val_accuracy did not improve from 0.25510
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6704 - accuracy: 0.7526 - val_loss: 18.7124 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 11/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5916 - accuracy: 0.7734
# Epoch 11: val_accuracy did not improve from 0.25510
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6189 - accuracy: 0.7691 - val_loss: 16.0025 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 12/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6211 - accuracy: 0.7695
# Epoch 12: val_accuracy improved from 0.25510 to 0.30612, saving model to D:/research/2025_iris_taufik/MultimodalEmoLearn/models\landmark_model_best.h5
# 4/4 [==============================] - 0s 86ms/step - loss: 0.5632 - accuracy: 0.7934 - val_loss: 14.6520 - val_accuracy: 0.3061 - lr: 0.0010
# Epoch 13/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5600 - accuracy: 0.7930
# Epoch 13: val_accuracy did not improve from 0.30612
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5685 - accuracy: 0.7883 - val_loss: 17.4836 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 14/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5039 - accuracy: 0.8203
# Epoch 14: val_accuracy did not improve from 0.30612
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5364 - accuracy: 0.8151 - val_loss: 21.8061 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 15/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5247 - accuracy: 0.8203
# Epoch 15: val_accuracy did not improve from 0.30612
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5239 - accuracy: 0.8099 - val_loss: 25.0510 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 16/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5284 - accuracy: 0.8398
# Epoch 16: val_accuracy did not improve from 0.30612
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5088 - accuracy: 0.8278 - val_loss: 27.8041 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 17/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4827 - accuracy: 0.8398
# Epoch 17: val_accuracy did not improve from 0.30612
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4766 - accuracy: 0.8444 - val_loss: 27.1508 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 18/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4530 - accuracy: 0.8320
# Epoch 18: val_accuracy did not improve from 0.30612
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4465 - accuracy: 0.8469 - val_loss: 24.2036 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 19/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5618 - accuracy: 0.8008
# Epoch 19: val_accuracy did not improve from 0.30612
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4817 - accuracy: 0.8316 - val_loss: 22.0129 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 20/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5301 - accuracy: 0.8281
# Epoch 20: val_accuracy did not improve from 0.30612
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4598 - accuracy: 0.8495 - val_loss: 21.2508 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 21/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4248 - accuracy: 0.8242
# Epoch 21: val_accuracy did not improve from 0.30612
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4403 - accuracy: 0.8355 - val_loss: 20.9006 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 22/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4640 - accuracy: 0.8398
# Epoch 22: val_accuracy did not improve from 0.30612
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4120 - accuracy: 0.8648 - val_loss: 20.0647 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 23/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3629 - accuracy: 0.8711
# Epoch 23: val_accuracy did not improve from 0.30612
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4046 - accuracy: 0.8661 - val_loss: 18.6615 - val_accuracy: 0.2551 - lr: 5.0000e-04
# Epoch 24/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4126 - accuracy: 0.8828
# Epoch 24: val_accuracy did not improve from 0.30612
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3891 - accuracy: 0.8724 - val_loss: 15.9551 - val_accuracy: 0.2551 - lr: 5.0000e-04
# Epoch 25/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4080 - accuracy: 0.8477
# Epoch 25: val_accuracy did not improve from 0.30612
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3831 - accuracy: 0.8635 - val_loss: 14.2225 - val_accuracy: 0.2551 - lr: 5.0000e-04
# Epoch 26/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3506 - accuracy: 0.9219
# Epoch 26: val_accuracy did not improve from 0.30612
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3861 - accuracy: 0.8776 - val_loss: 12.2930 - val_accuracy: 0.2551 - lr: 5.0000e-04
# Epoch 27/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3403 - accuracy: 0.8906
# Epoch 27: val_accuracy did not improve from 0.30612
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3953 - accuracy: 0.8635 - val_loss: 11.3117 - val_accuracy: 0.2551 - lr: 5.0000e-04
# Epoch 28/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3714 - accuracy: 0.8867
# Epoch 28: val_accuracy did not improve from 0.30612
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3823 - accuracy: 0.8750 - val_loss: 11.6208 - val_accuracy: 0.2551 - lr: 5.0000e-04
# Epoch 29/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3279 - accuracy: 0.8906
# Epoch 29: val_accuracy did not improve from 0.30612
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3563 - accuracy: 0.8801 - val_loss: 10.6866 - val_accuracy: 0.2551 - lr: 5.0000e-04
# Epoch 30/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3338 - accuracy: 0.9023
# Epoch 30: val_accuracy did not improve from 0.30612
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3519 - accuracy: 0.8967 - val_loss: 9.7282 - val_accuracy: 0.2551 - lr: 5.0000e-04
# Epoch 31/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3028 - accuracy: 0.8867
# Epoch 31: val_accuracy did not improve from 0.30612
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3584 - accuracy: 0.8724 - val_loss: 8.8380 - val_accuracy: 0.2551 - lr: 5.0000e-04
# Epoch 32/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3493 - accuracy: 0.8867
# Epoch 32: val_accuracy did not improve from 0.30612
# Restoring model weights from the end of the best epoch: 12.
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3646 - accuracy: 0.8763 - val_loss: 7.9959 - val_accuracy: 0.2551 - lr: 5.0000e-04
# Epoch 32: early stopping
# ✅ Training completed in 0.00 hours

# %% [markdown]
# ## 9. 📊 Evaluation

# %%
print("\n📊 Evaluating model...")

# Load best model
landmark_model = load_model(MODEL_PATH + 'landmark_model_best.h5')

# Evaluate on test set
test_loss, test_acc = landmark_model.evaluate(X_test_landmarks, y_test_onehot, verbose=0)
print(f"🎯 Test Accuracy: {test_acc:.4f}")
print(f"📉 Test Loss: {test_loss:.4f}")

# Detailed predictions
y_pred = np.argmax(landmark_model.predict(X_test_landmarks, batch_size=BATCH_SIZE), axis=1)
y_true = np.argmax(y_test_onehot, axis=1)

# Classification report
print("\n📈 Classification Report:")
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# 📊 Evaluating model...
# 🎯 Test Accuracy: 0.3367
# 📉 Test Loss: 14.2968
# 1/1 [==============================] - 0s 66ms/step
#
# 📈 Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.00      0.00      0.00        14
#     contempt       0.00      0.00      0.00         6
#    disgusted       0.00      0.00      0.00        17
#         fear       0.00      0.00      0.00         7
#        happy       0.80      0.38      0.52        21
#          sad       0.00      0.00      0.00         8
#    surprised       0.28      1.00      0.44        25
#
#     accuracy                           0.34        98
#    macro avg       0.15      0.20      0.14        98
# weighted avg       0.24      0.34      0.22        98
# c:\Users\fitra\miniconda3\envs\multimodal-emotion\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\fitra\miniconda3\envs\multimodal-emotion\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\fitra\miniconda3\envs\multimodal-emotion\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## 10. 📊 Visualization

# %%
print("📊 Creating visualizations...")

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens',
           xticklabels=target_names, yticklabels=target_names)
plt.title(f'Landmark Model Confusion Matrix (Test Acc: {test_acc:.4f})')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.savefig(MODEL_PATH + 'landmark_confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()

# Training history
if 'landmark_history' in locals():
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    # Accuracy plot
    axes[0].plot(landmark_history.history['accuracy'], label='Training Accuracy')
    axes[0].plot(landmark_history.history['val_accuracy'], label='Validation Accuracy')
    axes[0].set_title('Landmark Model Accuracy')
    axes[0].set_ylabel('Accuracy')
    axes[0].set_xlabel('Epoch')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)
    
    # Loss plot
    axes[1].plot(landmark_history.history['loss'], label='Training Loss')
    axes[1].plot(landmark_history.history['val_loss'], label='Validation Loss')
    axes[1].set_title('Landmark Model Loss')
    axes[1].set_ylabel('Loss')
    axes[1].set_xlabel('Epoch')
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(MODEL_PATH + 'landmark_training_history.png', dpi=300, bbox_inches='tight')
    plt.show()
# Out:
# 📊 Creating visualizations...

# %% [markdown]
# ## 11. 💾 Save Results

# %%
print("💾 Saving results...")

# Save training info
training_info = {
    'model_type': 'Landmark',
    'gpu_used': gpu_available,
    'num_gpus': num_gpus,
    'batch_size': BATCH_SIZE,
    'epochs_trained': len(landmark_history.history['accuracy']) if 'landmark_history' in locals() else 0,
    'test_accuracy': test_acc,
    'test_loss': test_loss,
    'total_parameters': landmark_model.count_params(),
    'training_time_hours': training_time/3600 if 'training_time' in locals() else 0,
    'device_info': f"AMD GPU ({num_gpus} device(s))" if gpu_available else "CPU"
}

with open(MODEL_PATH + 'landmark_training_info.pkl', 'wb') as f:
    pickle.dump(training_info, f)
# Out:
# 💾 Saving results...

# %% [markdown]
# ## 12. 📝 Summary

# %%
print("\n" + "=" * 60)
print("🎉 LANDMARK TRAINING COMPLETED!")
print("=" * 60)
print(f"📊 Final Test Accuracy: {test_acc:.4f}")
print(f"🎮 Device Used: {'AMD GPU' if gpu_available else 'CPU'}")
print(f"⏱️ Training Time: {training_time/3600:.2f} hours" if 'training_time' in locals() else "N/A")
print(f"💾 Model saved to: {MODEL_PATH}landmark_model_best.h5")
print(f"📈 Visualizations saved to: {MODEL_PATH}")
print("\n🚀 Ready for next step: Late Fusion!")
print("=" * 60)
# Out:
# ============================================================
# 🎉 LANDMARK TRAINING COMPLETED!
# ============================================================
# 📊 Final Test Accuracy: 0.3367
# 🎮 Device Used: AMD GPU
# ⏱️ Training Time: 0.00 hours
# 💾 Model saved to: D:/research/2025_iris_taufik/MultimodalEmoLearn/models/landmark_model_best.h5
# 📈 Visualizations saved to: D:/research/2025_iris_taufik/MultimodalEmoLearn/models/
#
# 🚀 Ready for next step: Late Fusion!
# ============================================================
