# %% [markdown]
# # 🎯 Landmark Model Training - Optimized for AMD GPU
#
# Training model landmark untuk klasifikasi emosi menggunakan facial landmarks dengan optimasi GPU.

# %% [markdown]
# ## 1. 📚 Import Libraries

# %%
import numpy as np
import tensorflow as tf
import os
import time
import pickle
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. 🎮 AMD GPU Setup

# %%
def setup_amd_gpu():
    """Setup AMD GPU with DirectML for optimal performance"""
    print("🎮 Setting up AMD GPU for Landmark Training...")
    
    try:
        gpu_devices = tf.config.list_physical_devices('GPU')
        dml_devices = tf.config.list_physical_devices('DML')
        total_devices = len(gpu_devices) + len(dml_devices)
        
        if total_devices > 0:
            print(f"✅ Found {total_devices} GPU device(s)")
            
            # Configure GPU memory growth
            for gpu in gpu_devices:
                tf.config.experimental.set_memory_growth(gpu, True)
            print("✅ GPU memory growth enabled")
            
            # Enable XLA compilation
            tf.config.optimizer.set_jit(True)
            print("✅ XLA compilation enabled")
            
            return True, total_devices
        else:
            print("⚠️ No GPU detected, using CPU")
            return False, 0
    except Exception as e:
        print(f"⚠️ GPU setup failed: {e}")
        return False, 0

# Setup GPU
gpu_available, num_gpus = setup_amd_gpu()
# Out:
# 🎮 Setting up AMD GPU for Landmark Training...
# ✅ Found 2 GPU device(s)
# ✅ GPU memory growth enabled
# ✅ XLA compilation enabled

# %% [markdown]
# ## 3. ⚙️ Konfigurasi Training

# %%
# GPU-optimized configurations
if gpu_available:
    BATCH_SIZE = 256  # Larger batch for landmarks (smaller data)
    EPOCHS = 150      # More epochs for landmarks
else:
    BATCH_SIZE = 64
    EPOCHS = 80

# Paths
BASE_PATH = 'D:/research/2025_iris_taufik/MultimodalEmoLearn/data/'
MODEL_PATH = 'D:/research/2025_iris_taufik/MultimodalEmoLearn/models/'

print(f"🎯 Landmark Training Configuration:")
print(f"   Device: {'AMD GPU' if gpu_available else 'CPU'}")
print(f"   Batch Size: {BATCH_SIZE}")
print(f"   Max Epochs: {EPOCHS}")
# Out:
# 🎯 Landmark Training Configuration:
#    Device: AMD GPU
#    Batch Size: 256
#    Max Epochs: 150

# %% [markdown]
# ## 4. 📁 Load Data

# %%
print("📁 Loading landmark data...")

try:
    # Load landmark features
    X_train_landmarks = np.load(BASE_PATH + 'landmarks/X_train_landmarks.npy')
    X_val_landmarks = np.load(BASE_PATH + 'landmarks/X_val_landmarks.npy')
    X_test_landmarks = np.load(BASE_PATH + 'landmarks/X_test_landmarks.npy')
    
    # Load labels
    y_train = np.load(BASE_PATH + 'landmarks/y_train_landmarks.npy')
    y_val = np.load(BASE_PATH + 'landmarks/y_val_landmarks.npy')
    y_test = np.load(BASE_PATH + 'landmarks/y_test_landmarks.npy')
    
    print(f"✅ Landmark data loaded successfully!")
    print(f"Training samples: {X_train_landmarks.shape[0]:,}")
    print(f"Validation samples: {X_val_landmarks.shape[0]:,}")
    print(f"Test samples: {X_test_landmarks.shape[0]:,}")
    print(f"Landmark features: {X_train_landmarks.shape[1]}")
    
except Exception as e:
    print(f"❌ Error loading data: {e}")
    exit(1)
# Out:
# 📁 Loading landmark data...
# ✅ Landmark data loaded successfully!
# Training samples: 784
# Validation samples: 98
# Test samples: 98
# Landmark features: 136

# %% [markdown]
# ## 5. 🏷️ Load Label Mapping

# %%
print("🏷️ Loading label mapping...")

try:
    with open(MODEL_PATH + 'label_map.pkl', 'rb') as f:
        label_map = pickle.load(f)
    
    num_classes = len(label_map)
    target_names = list(label_map.keys())
    
    print(f"Classes: {target_names}")
    print(f"Number of classes: {num_classes}")
    
except FileNotFoundError:
    print("❌ Label mapping not found! Please train CNN model first.")
    exit(1)

# Convert labels
y_train_num = np.array([label_map[label] for label in y_train])
y_val_num = np.array([label_map[label] for label in y_val])
y_test_num = np.array([label_map[label] for label in y_test])

# One-hot encoding
y_train_onehot = to_categorical(y_train_num, num_classes)
y_val_onehot = to_categorical(y_val_num, num_classes)
y_test_onehot = to_categorical(y_test_num, num_classes)

print("✅ Label preprocessing completed")
# Out:
# 🏷️ Loading label mapping...
# Classes: ['angry', 'contempt', 'disgusted', 'fear', 'happy', 'sad', 'surprised']
# Number of classes: 7
# ✅ Label preprocessing completed

# %% [markdown]
# ## 6. 🧠 Build Landmark Model

# %%
def build_optimized_landmark_model(input_dim, num_classes):
    """Build landmark model optimized for GPU training"""
    
    device_context = '/GPU:0' if gpu_available else '/CPU:0'
    
    with tf.device(device_context):
        model = Sequential([
            # Input layer
            Dense(512 if gpu_available else 256, activation='relu', input_dim=input_dim),
            BatchNormalization(),
            Dropout(0.3),
            
            # Hidden layers - more complex for GPU
            Dense(256 if gpu_available else 128, activation='relu'),
            BatchNormalization(),
            Dropout(0.4),
            
            Dense(128 if gpu_available else 64, activation='relu'),
            BatchNormalization(),
            Dropout(0.3),
            
            # Additional layer for GPU
            Dense(64, activation='relu') if gpu_available else Dense(32, activation='relu'),
            BatchNormalization(),
            Dropout(0.2),
            
            # Output layer
            Dense(num_classes, activation='softmax')
        ])
    
    # Compile with optimized learning rate
    learning_rate = 0.001 if gpu_available else 0.01
    
    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %% [markdown]
# ## 7. 🔧 Setup Callbacks

# %%
print("⚙️ Setting up callbacks...")

# Model checkpoint
checkpoint = ModelCheckpoint(
    MODEL_PATH + 'landmark_model_best.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

# Early stopping
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=20 if gpu_available else 15,
    restore_best_weights=True,
    verbose=1,
    mode='max'
)

# Learning rate reduction
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=10 if gpu_available else 7,
    min_lr=1e-7,
    verbose=1
)

callbacks = [checkpoint, early_stopping, reduce_lr]
# Out:
# ⚙️ Setting up callbacks...

# %% [markdown]
# ## 8. 🚀 Train Model

# %%
print(f"🚀 Training Landmark model on {'GPU' if gpu_available else 'CPU'}...")
print("=" * 60)

# Build model
landmark_model = build_optimized_landmark_model(X_train_landmarks.shape[1], num_classes)

print("📊 Model Summary:")
print(f"Total Parameters: {landmark_model.count_params():,}")
trainable_params = sum([tf.size(w).numpy() for w in landmark_model.trainable_weights])
print(f"Trainable Parameters: {trainable_params:,}")

# Training
start_time = time.time()

try:
    device_context = '/GPU:0' if gpu_available else '/CPU:0'
    
    with tf.device(device_context):
        landmark_history = landmark_model.fit(
            X_train_landmarks,
            y_train_onehot,
            batch_size=BATCH_SIZE,
            epochs=EPOCHS,
            validation_data=(X_val_landmarks, y_val_onehot),
            callbacks=callbacks,
            verbose=1
        )
    
    training_time = time.time() - start_time
    print(f"✅ Training completed in {training_time/3600:.2f} hours")
    
except Exception as e:
    print(f"❌ Training failed: {e}")
    if gpu_available and 'memory' in str(e).lower():
        print("💡 Retrying with smaller batch size...")
        BATCH_SIZE = 64
        landmark_history = landmark_model.fit(
            X_train_landmarks,
            y_train_onehot,
            batch_size=BATCH_SIZE,
            epochs=EPOCHS,
            validation_data=(X_val_landmarks, y_val_onehot),
            callbacks=callbacks,
            verbose=1
        )
# Out:
# 🚀 Training Landmark model on GPU...
# ============================================================
# 📊 Model Summary:
# Total Parameters: 246,919
# Trainable Parameters: 244,999
# Epoch 1/150
# 1/4 [======>.......................] - ETA: 2s - loss: 2.6863 - accuracy: 0.1953
# Epoch 1: val_accuracy improved from -inf to 0.25510, saving model to D:/research/2025_iris_taufik/MultimodalEmoLearn/models\landmark_model_best.h5
# 4/4 [==============================] - 1s 144ms/step - loss: 2.2737 - accuracy: 0.2436 - val_loss: 30.0662 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 2/150
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3790 - accuracy: 0.5039
# Epoch 2: val_accuracy did not improve from 0.25510
# 4/4 [==============================] - 0s 15ms/step - loss: 1.3109 - accuracy: 0.5230 - val_loss: 36.9669 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 3/150
# 1/4 [======>.......................] - ETA: 0s - loss: 1.1393 - accuracy: 0.6094
# Epoch 3: val_accuracy did not improve from 0.25510
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0890 - accuracy: 0.6339 - val_loss: 38.5135 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 4/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.9810 - accuracy: 0.6328
# Epoch 4: val_accuracy did not improve from 0.25510
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8991 - accuracy: 0.6811 - val_loss: 34.7619 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 5/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.9032 - accuracy: 0.6914
# Epoch 5: val_accuracy did not improve from 0.25510
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8262 - accuracy: 0.7028 - val_loss: 30.3136 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 6/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7539 - accuracy: 0.7070
# Epoch 6: val_accuracy did not improve from 0.25510
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7511 - accuracy: 0.7054 - val_loss: 25.7464 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 7/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6599 - accuracy: 0.7578
# Epoch 7: val_accuracy did not improve from 0.25510
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7226 - accuracy: 0.7334 - val_loss: 19.5048 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 8/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6080 - accuracy: 0.7695
# Epoch 8: val_accuracy improved from 0.25510 to 0.26531, saving model to D:/research/2025_iris_taufik/MultimodalEmoLearn/models\landmark_model_best.h5
# 4/4 [==============================] - 0s 85ms/step - loss: 0.6731 - accuracy: 0.7577 - val_loss: 15.6195 - val_accuracy: 0.2653 - lr: 0.0010
# Epoch 9/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6211 - accuracy: 0.7656
# Epoch 9: val_accuracy did not improve from 0.26531
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6745 - accuracy: 0.7564 - val_loss: 15.4799 - val_accuracy: 0.2653 - lr: 0.0010
# Epoch 10/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5814 - accuracy: 0.7969
# Epoch 10: val_accuracy did not improve from 0.26531
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5718 - accuracy: 0.7921 - val_loss: 15.1152 - val_accuracy: 0.2653 - lr: 0.0010
# Epoch 11/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5407 - accuracy: 0.8242
# Epoch 11: val_accuracy did not improve from 0.26531
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5919 - accuracy: 0.7934 - val_loss: 14.8066 - val_accuracy: 0.2653 - lr: 0.0010
# Epoch 12/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5622 - accuracy: 0.7891
# Epoch 12: val_accuracy did not improve from 0.26531
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5470 - accuracy: 0.8087 - val_loss: 15.0100 - val_accuracy: 0.2653 - lr: 0.0010
# Epoch 13/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5766 - accuracy: 0.7812
# Epoch 13: val_accuracy did not improve from 0.26531
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5404 - accuracy: 0.8048 - val_loss: 14.3956 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 14/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5365 - accuracy: 0.8164
# Epoch 14: val_accuracy did not improve from 0.26531
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5398 - accuracy: 0.8163 - val_loss: 13.1030 - val_accuracy: 0.2551 - lr: 0.0010
# Epoch 15/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5436 - accuracy: 0.8281
# Epoch 15: val_accuracy did not improve from 0.26531
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4914 - accuracy: 0.8431 - val_loss: 10.6402 - val_accuracy: 0.2653 - lr: 0.0010
# Epoch 16/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4693 - accuracy: 0.8203
# Epoch 16: val_accuracy improved from 0.26531 to 0.33673, saving model to D:/research/2025_iris_taufik/MultimodalEmoLearn/models\landmark_model_best.h5
# 4/4 [==============================] - 0s 102ms/step - loss: 0.4656 - accuracy: 0.8355 - val_loss: 8.8658 - val_accuracy: 0.3367 - lr: 0.0010
# Epoch 17/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4083 - accuracy: 0.8555
# Epoch 17: val_accuracy improved from 0.33673 to 0.37755, saving model to D:/research/2025_iris_taufik/MultimodalEmoLearn/models\landmark_model_best.h5
# 4/4 [==============================] - 0s 77ms/step - loss: 0.4534 - accuracy: 0.8316 - val_loss: 7.7186 - val_accuracy: 0.3776 - lr: 0.0010
# Epoch 18/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4709 - accuracy: 0.8281
# Epoch 18: val_accuracy improved from 0.37755 to 0.45918, saving model to D:/research/2025_iris_taufik/MultimodalEmoLearn/models\landmark_model_best.h5
# 4/4 [==============================] - 0s 78ms/step - loss: 0.4527 - accuracy: 0.8342 - val_loss: 7.0343 - val_accuracy: 0.4592 - lr: 0.0010
# Epoch 19/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4464 - accuracy: 0.8242
# Epoch 19: val_accuracy improved from 0.45918 to 0.50000, saving model to D:/research/2025_iris_taufik/MultimodalEmoLearn/models\landmark_model_best.h5
# 4/4 [==============================] - 0s 75ms/step - loss: 0.4426 - accuracy: 0.8406 - val_loss: 5.7907 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 20/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3614 - accuracy: 0.8750
# Epoch 20: val_accuracy did not improve from 0.50000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4134 - accuracy: 0.8546 - val_loss: 5.2483 - val_accuracy: 0.4592 - lr: 0.0010
# Epoch 21/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3837 - accuracy: 0.8828
# Epoch 21: val_accuracy did not improve from 0.50000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3852 - accuracy: 0.8699 - val_loss: 5.2191 - val_accuracy: 0.3469 - lr: 0.0010
# Epoch 22/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4209 - accuracy: 0.8516
# Epoch 22: val_accuracy did not improve from 0.50000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4205 - accuracy: 0.8559 - val_loss: 4.3954 - val_accuracy: 0.4286 - lr: 0.0010
# Epoch 23/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4484 - accuracy: 0.8516
# Epoch 23: val_accuracy improved from 0.50000 to 0.53061, saving model to D:/research/2025_iris_taufik/MultimodalEmoLearn/models\landmark_model_best.h5
# 4/4 [==============================] - 0s 84ms/step - loss: 0.3972 - accuracy: 0.8648 - val_loss: 4.4350 - val_accuracy: 0.5306 - lr: 0.0010
# Epoch 24/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3645 - accuracy: 0.8867
# Epoch 24: val_accuracy did not improve from 0.53061
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3663 - accuracy: 0.8865 - val_loss: 4.3654 - val_accuracy: 0.4592 - lr: 0.0010
# Epoch 25/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4253 - accuracy: 0.8594
# Epoch 25: val_accuracy did not improve from 0.53061
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3708 - accuracy: 0.8788 - val_loss: 4.5616 - val_accuracy: 0.4184 - lr: 0.0010
# Epoch 26/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4067 - accuracy: 0.8594
# Epoch 26: val_accuracy did not improve from 0.53061
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3721 - accuracy: 0.8801 - val_loss: 5.4110 - val_accuracy: 0.3776 - lr: 0.0010
# Epoch 27/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3591 - accuracy: 0.8750
# Epoch 27: val_accuracy did not improve from 0.53061
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3761 - accuracy: 0.8737 - val_loss: 7.8581 - val_accuracy: 0.1735 - lr: 0.0010
# Epoch 28/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3617 - accuracy: 0.8672
# Epoch 28: val_accuracy did not improve from 0.53061
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3571 - accuracy: 0.8686 - val_loss: 10.8891 - val_accuracy: 0.1633 - lr: 0.0010
# Epoch 29/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3361 - accuracy: 0.8867
# Epoch 29: val_accuracy did not improve from 0.53061
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3280 - accuracy: 0.8890 - val_loss: 10.9066 - val_accuracy: 0.1327 - lr: 0.0010
# Epoch 30/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3269 - accuracy: 0.8828
# Epoch 30: val_accuracy did not improve from 0.53061
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3312 - accuracy: 0.8827 - val_loss: 10.2800 - val_accuracy: 0.1327 - lr: 0.0010
# Epoch 31/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2601 - accuracy: 0.9297
# Epoch 31: val_accuracy did not improve from 0.53061
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3006 - accuracy: 0.9031 - val_loss: 7.9675 - val_accuracy: 0.1327 - lr: 0.0010
# Epoch 32/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3311 - accuracy: 0.8828
# Epoch 32: val_accuracy did not improve from 0.53061
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3009 - accuracy: 0.9043 - val_loss: 4.9645 - val_accuracy: 0.2143 - lr: 0.0010
# Epoch 33/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3024 - accuracy: 0.8984
# Epoch 33: val_accuracy did not improve from 0.53061
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3179 - accuracy: 0.8941 - val_loss: 3.8149 - val_accuracy: 0.3265 - lr: 0.0010
# Epoch 34/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3393 - accuracy: 0.8594
# Epoch 34: val_accuracy did not improve from 0.53061
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3003 - accuracy: 0.8890 - val_loss: 4.2515 - val_accuracy: 0.2653 - lr: 0.0010
# Epoch 35/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2705 - accuracy: 0.9219
# Epoch 35: val_accuracy did not improve from 0.53061
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2680 - accuracy: 0.9082 - val_loss: 5.9281 - val_accuracy: 0.1735 - lr: 0.0010
# Epoch 36/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2879 - accuracy: 0.9141
# Epoch 36: val_accuracy did not improve from 0.53061
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2757 - accuracy: 0.9158 - val_loss: 7.4416 - val_accuracy: 0.1531 - lr: 0.0010
# Epoch 37/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2496 - accuracy: 0.9141
# Epoch 37: val_accuracy did not improve from 0.53061
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2817 - accuracy: 0.8992 - val_loss: 4.2623 - val_accuracy: 0.3776 - lr: 0.0010
# Epoch 38/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2062 - accuracy: 0.9336
# Epoch 38: val_accuracy improved from 0.53061 to 0.58163, saving model to D:/research/2025_iris_taufik/MultimodalEmoLearn/models\landmark_model_best.h5
# 4/4 [==============================] - 0s 84ms/step - loss: 0.2577 - accuracy: 0.9196 - val_loss: 2.5176 - val_accuracy: 0.5816 - lr: 0.0010
# Epoch 39/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2523 - accuracy: 0.9141
# Epoch 39: val_accuracy improved from 0.58163 to 0.59184, saving model to D:/research/2025_iris_taufik/MultimodalEmoLearn/models\landmark_model_best.h5
# 4/4 [==============================] - 0s 77ms/step - loss: 0.2501 - accuracy: 0.9273 - val_loss: 1.4669 - val_accuracy: 0.5918 - lr: 0.0010
# Epoch 40/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2714 - accuracy: 0.9141
# Epoch 40: val_accuracy did not improve from 0.59184
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2770 - accuracy: 0.9158 - val_loss: 1.6322 - val_accuracy: 0.5918 - lr: 0.0010
# Epoch 41/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2069 - accuracy: 0.9492
# Epoch 41: val_accuracy did not improve from 0.59184
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2525 - accuracy: 0.9222 - val_loss: 4.4135 - val_accuracy: 0.3163 - lr: 0.0010
# Epoch 42/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2745 - accuracy: 0.9141
# Epoch 42: val_accuracy did not improve from 0.59184
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2443 - accuracy: 0.9196 - val_loss: 5.1238 - val_accuracy: 0.3061 - lr: 0.0010
# Epoch 43/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1970 - accuracy: 0.9531
# Epoch 43: val_accuracy did not improve from 0.59184
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2311 - accuracy: 0.9273 - val_loss: 3.3830 - val_accuracy: 0.4286 - lr: 0.0010
# Epoch 44/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1978 - accuracy: 0.9414
# Epoch 44: val_accuracy did not improve from 0.59184
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2317 - accuracy: 0.9247 - val_loss: 2.4191 - val_accuracy: 0.5918 - lr: 0.0010
# Epoch 45/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2130 - accuracy: 0.9414
# Epoch 45: val_accuracy improved from 0.59184 to 0.65306, saving model to D:/research/2025_iris_taufik/MultimodalEmoLearn/models\landmark_model_best.h5
# 4/4 [==============================] - 0s 83ms/step - loss: 0.2218 - accuracy: 0.9349 - val_loss: 2.0940 - val_accuracy: 0.6531 - lr: 0.0010
# Epoch 46/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2224 - accuracy: 0.9297
# Epoch 46: val_accuracy did not improve from 0.65306
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2087 - accuracy: 0.9337 - val_loss: 2.4972 - val_accuracy: 0.5102 - lr: 0.0010
# Epoch 47/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1994 - accuracy: 0.9336
# Epoch 47: val_accuracy did not improve from 0.65306
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2104 - accuracy: 0.9298 - val_loss: 4.6918 - val_accuracy: 0.2347 - lr: 0.0010
# Epoch 48/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1609 - accuracy: 0.9570
# Epoch 48: val_accuracy did not improve from 0.65306
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2167 - accuracy: 0.9311 - val_loss: 4.9904 - val_accuracy: 0.1122 - lr: 0.0010
# Epoch 49/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1777 - accuracy: 0.9375
# Epoch 49: val_accuracy did not improve from 0.65306
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1839 - accuracy: 0.9375 - val_loss: 2.9647 - val_accuracy: 0.2347 - lr: 0.0010
# Epoch 50/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1961 - accuracy: 0.9414
# Epoch 50: val_accuracy did not improve from 0.65306
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2148 - accuracy: 0.9247 - val_loss: 2.1743 - val_accuracy: 0.4490 - lr: 5.0000e-04
# Epoch 51/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1545 - accuracy: 0.9648
# Epoch 51: val_accuracy did not improve from 0.65306
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1912 - accuracy: 0.9401 - val_loss: 3.3885 - val_accuracy: 0.3673 - lr: 5.0000e-04
# Epoch 52/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2060 - accuracy: 0.9336
# Epoch 52: val_accuracy did not improve from 0.65306
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2047 - accuracy: 0.9337 - val_loss: 4.0092 - val_accuracy: 0.2959 - lr: 5.0000e-04
# Epoch 53/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2196 - accuracy: 0.9180
# Epoch 53: val_accuracy did not improve from 0.65306
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1988 - accuracy: 0.9362 - val_loss: 1.6375 - val_accuracy: 0.6531 - lr: 5.0000e-04
# Epoch 54/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1694 - accuracy: 0.9375
# Epoch 54: val_accuracy did not improve from 0.65306
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1899 - accuracy: 0.9375 - val_loss: 2.5219 - val_accuracy: 0.4796 - lr: 5.0000e-04
# Epoch 55/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1787 - accuracy: 0.9336
# Epoch 55: val_accuracy did not improve from 0.65306
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2019 - accuracy: 0.9286 - val_loss: 3.5608 - val_accuracy: 0.4184 - lr: 5.0000e-04
# Epoch 56/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2517 - accuracy: 0.9023
# Epoch 56: val_accuracy did not improve from 0.65306
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2055 - accuracy: 0.9324 - val_loss: 3.8409 - val_accuracy: 0.4082 - lr: 5.0000e-04
# Epoch 57/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2110 - accuracy: 0.9180
# Epoch 57: val_accuracy did not improve from 0.65306
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2251 - accuracy: 0.9247 - val_loss: 3.7889 - val_accuracy: 0.4082 - lr: 5.0000e-04
# Epoch 58/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1900 - accuracy: 0.9492
# Epoch 58: val_accuracy did not improve from 0.65306
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1927 - accuracy: 0.9375 - val_loss: 3.3656 - val_accuracy: 0.4184 - lr: 5.0000e-04
# Epoch 59/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1748 - accuracy: 0.9453
# Epoch 59: val_accuracy did not improve from 0.65306
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1898 - accuracy: 0.9349 - val_loss: 2.5466 - val_accuracy: 0.4490 - lr: 5.0000e-04
# Epoch 60/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1633 - accuracy: 0.9453
# Epoch 60: val_accuracy did not improve from 0.65306
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1683 - accuracy: 0.9490 - val_loss: 2.1106 - val_accuracy: 0.5102 - lr: 2.5000e-04
# Epoch 61/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2162 - accuracy: 0.9258
# Epoch 61: val_accuracy did not improve from 0.65306
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2069 - accuracy: 0.9337 - val_loss: 1.7328 - val_accuracy: 0.5816 - lr: 2.5000e-04
# Epoch 62/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1847 - accuracy: 0.9336
# Epoch 62: val_accuracy did not improve from 0.65306
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2007 - accuracy: 0.9324 - val_loss: 1.5375 - val_accuracy: 0.6327 - lr: 2.5000e-04
# Epoch 63/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1964 - accuracy: 0.9336
# Epoch 63: val_accuracy improved from 0.65306 to 0.66327, saving model to D:/research/2025_iris_taufik/MultimodalEmoLearn/models\landmark_model_best.h5
# 4/4 [==============================] - 0s 79ms/step - loss: 0.1940 - accuracy: 0.9324 - val_loss: 1.4705 - val_accuracy: 0.6633 - lr: 2.5000e-04
# Epoch 64/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1279 - accuracy: 0.9648
# Epoch 64: val_accuracy did not improve from 0.66327
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1614 - accuracy: 0.9477 - val_loss: 1.4452 - val_accuracy: 0.6633 - lr: 2.5000e-04
# Epoch 65/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1728 - accuracy: 0.9336
# Epoch 65: val_accuracy did not improve from 0.66327
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1721 - accuracy: 0.9388 - val_loss: 1.2221 - val_accuracy: 0.6633 - lr: 2.5000e-04
# Epoch 66/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1958 - accuracy: 0.9375
# Epoch 66: val_accuracy did not improve from 0.66327
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1580 - accuracy: 0.9554 - val_loss: 1.0770 - val_accuracy: 0.6224 - lr: 2.5000e-04
# Epoch 67/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2130 - accuracy: 0.9336
# Epoch 67: val_accuracy did not improve from 0.66327
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1835 - accuracy: 0.9477 - val_loss: 1.0393 - val_accuracy: 0.6327 - lr: 2.5000e-04
# Epoch 68/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1746 - accuracy: 0.9531
# Epoch 68: val_accuracy did not improve from 0.66327
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1856 - accuracy: 0.9413 - val_loss: 0.9659 - val_accuracy: 0.6531 - lr: 2.5000e-04
# Epoch 69/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1709 - accuracy: 0.9570
# Epoch 69: val_accuracy improved from 0.66327 to 0.70408, saving model to D:/research/2025_iris_taufik/MultimodalEmoLearn/models\landmark_model_best.h5
# 4/4 [==============================] - 0s 80ms/step - loss: 0.1931 - accuracy: 0.9464 - val_loss: 0.9830 - val_accuracy: 0.7041 - lr: 2.5000e-04
# Epoch 70/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1453 - accuracy: 0.9609
# Epoch 70: val_accuracy did not improve from 0.70408
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1799 - accuracy: 0.9426 - val_loss: 1.1216 - val_accuracy: 0.7041 - lr: 2.5000e-04
# Epoch 71/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2084 - accuracy: 0.9297
# Epoch 71: val_accuracy did not improve from 0.70408
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1838 - accuracy: 0.9452 - val_loss: 1.3535 - val_accuracy: 0.6735 - lr: 2.5000e-04
# Epoch 72/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1743 - accuracy: 0.9453
# Epoch 72: val_accuracy did not improve from 0.70408
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1684 - accuracy: 0.9490 - val_loss: 1.5353 - val_accuracy: 0.5408 - lr: 2.5000e-04
# Epoch 73/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1631 - accuracy: 0.9531
# Epoch 73: val_accuracy did not improve from 0.70408
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1647 - accuracy: 0.9464 - val_loss: 1.4977 - val_accuracy: 0.5714 - lr: 2.5000e-04
# Epoch 74/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1960 - accuracy: 0.9453
# Epoch 74: val_accuracy did not improve from 0.70408
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1715 - accuracy: 0.9528 - val_loss: 1.4871 - val_accuracy: 0.6122 - lr: 2.5000e-04
# Epoch 75/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1659 - accuracy: 0.9609
# Epoch 75: val_accuracy did not improve from 0.70408
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1667 - accuracy: 0.9554 - val_loss: 1.5743 - val_accuracy: 0.6122 - lr: 2.5000e-04
# Epoch 76/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1461 - accuracy: 0.9609
# Epoch 76: val_accuracy did not improve from 0.70408
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1801 - accuracy: 0.9477 - val_loss: 1.5826 - val_accuracy: 0.6327 - lr: 2.5000e-04
# Epoch 77/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1671 - accuracy: 0.9492
# Epoch 77: val_accuracy did not improve from 0.70408
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1673 - accuracy: 0.9452 - val_loss: 1.5849 - val_accuracy: 0.6020 - lr: 2.5000e-04
# Epoch 78/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1635 - accuracy: 0.9414
# Epoch 78: val_accuracy did not improve from 0.70408
#
# Epoch 78: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1648 - accuracy: 0.9490 - val_loss: 1.5862 - val_accuracy: 0.6224 - lr: 2.5000e-04
# Epoch 79/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1361 - accuracy: 0.9648
# Epoch 79: val_accuracy did not improve from 0.70408
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1822 - accuracy: 0.9464 - val_loss: 1.7349 - val_accuracy: 0.5816 - lr: 1.2500e-04
# Epoch 80/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1663 - accuracy: 0.9531
# Epoch 80: val_accuracy did not improve from 0.70408
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1567 - accuracy: 0.9541 - val_loss: 2.0478 - val_accuracy: 0.5306 - lr: 1.2500e-04
# Epoch 81/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1406 - accuracy: 0.9492
# Epoch 81: val_accuracy did not improve from 0.70408
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1603 - accuracy: 0.9490 - val_loss: 2.2064 - val_accuracy: 0.5000 - lr: 1.2500e-04
# Epoch 82/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1359 - accuracy: 0.9570
# Epoch 82: val_accuracy did not improve from 0.70408
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1541 - accuracy: 0.9515 - val_loss: 2.1423 - val_accuracy: 0.5204 - lr: 1.2500e-04
# Epoch 83/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1332 - accuracy: 0.9688
# Epoch 83: val_accuracy did not improve from 0.70408
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1562 - accuracy: 0.9490 - val_loss: 1.8625 - val_accuracy: 0.5510 - lr: 1.2500e-04
# Epoch 84/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1163 - accuracy: 0.9648
# Epoch 84: val_accuracy did not improve from 0.70408
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1449 - accuracy: 0.9541 - val_loss: 1.6507 - val_accuracy: 0.6429 - lr: 1.2500e-04
# Epoch 85/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1290 - accuracy: 0.9688
# Epoch 85: val_accuracy improved from 0.70408 to 0.73469, saving model to D:/research/2025_iris_taufik/MultimodalEmoLearn/models\landmark_model_best.h5
# 4/4 [==============================] - 1s 189ms/step - loss: 0.1431 - accuracy: 0.9541 - val_loss: 1.4453 - val_accuracy: 0.7347 - lr: 1.2500e-04
# Epoch 86/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1581 - accuracy: 0.9570
# Epoch 86: val_accuracy improved from 0.73469 to 0.74490, saving model to D:/research/2025_iris_taufik/MultimodalEmoLearn/models\landmark_model_best.h5
# 4/4 [==============================] - 0s 80ms/step - loss: 0.1529 - accuracy: 0.9592 - val_loss: 1.3519 - val_accuracy: 0.7449 - lr: 1.2500e-04
# Epoch 87/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1843 - accuracy: 0.9453
# Epoch 87: val_accuracy did not improve from 0.74490
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1713 - accuracy: 0.9464 - val_loss: 1.2973 - val_accuracy: 0.7245 - lr: 1.2500e-04
# Epoch 88/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1824 - accuracy: 0.9453
# Epoch 88: val_accuracy did not improve from 0.74490
#
# Epoch 88: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1657 - accuracy: 0.9528 - val_loss: 1.2151 - val_accuracy: 0.7347 - lr: 1.2500e-04
# Epoch 89/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1697 - accuracy: 0.9414
# Epoch 89: val_accuracy did not improve from 0.74490
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1606 - accuracy: 0.9464 - val_loss: 1.1411 - val_accuracy: 0.7245 - lr: 6.2500e-05
# Epoch 90/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2010 - accuracy: 0.9414
# Epoch 90: val_accuracy did not improve from 0.74490
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1740 - accuracy: 0.9515 - val_loss: 1.0645 - val_accuracy: 0.7041 - lr: 6.2500e-05
# Epoch 91/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1278 - accuracy: 0.9727
# Epoch 91: val_accuracy did not improve from 0.74490
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1532 - accuracy: 0.9541 - val_loss: 1.0129 - val_accuracy: 0.7041 - lr: 6.2500e-05
# Epoch 92/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1480 - accuracy: 0.9570
# Epoch 92: val_accuracy did not improve from 0.74490
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1554 - accuracy: 0.9554 - val_loss: 1.0139 - val_accuracy: 0.6837 - lr: 6.2500e-05
# Epoch 93/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1422 - accuracy: 0.9492
# Epoch 93: val_accuracy did not improve from 0.74490
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1357 - accuracy: 0.9554 - val_loss: 0.9819 - val_accuracy: 0.6939 - lr: 6.2500e-05
# Epoch 94/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2050 - accuracy: 0.9336
# Epoch 94: val_accuracy did not improve from 0.74490
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1699 - accuracy: 0.9464 - val_loss: 0.9406 - val_accuracy: 0.7041 - lr: 6.2500e-05
# Epoch 95/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1372 - accuracy: 0.9609
# Epoch 95: val_accuracy did not improve from 0.74490
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1692 - accuracy: 0.9541 - val_loss: 0.8902 - val_accuracy: 0.7143 - lr: 6.2500e-05
# Epoch 96/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1928 - accuracy: 0.9336
# Epoch 96: val_accuracy did not improve from 0.74490
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1628 - accuracy: 0.9528 - val_loss: 0.8545 - val_accuracy: 0.7143 - lr: 6.2500e-05
# Epoch 97/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1208 - accuracy: 0.9766
# Epoch 97: val_accuracy did not improve from 0.74490
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1577 - accuracy: 0.9541 - val_loss: 0.7974 - val_accuracy: 0.7143 - lr: 6.2500e-05
# Epoch 98/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1691 - accuracy: 0.9492
# Epoch 98: val_accuracy did not improve from 0.74490
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1580 - accuracy: 0.9515 - val_loss: 0.7659 - val_accuracy: 0.7245 - lr: 6.2500e-05
# Epoch 99/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1526 - accuracy: 0.9570
# Epoch 99: val_accuracy did not improve from 0.74490
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1546 - accuracy: 0.9566 - val_loss: 0.7466 - val_accuracy: 0.7347 - lr: 6.2500e-05
# Epoch 100/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1558 - accuracy: 0.9492
# Epoch 100: val_accuracy did not improve from 0.74490
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1581 - accuracy: 0.9515 - val_loss: 0.7335 - val_accuracy: 0.7449 - lr: 6.2500e-05
# Epoch 101/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1426 - accuracy: 0.9492
# Epoch 101: val_accuracy did not improve from 0.74490
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1464 - accuracy: 0.9528 - val_loss: 0.7595 - val_accuracy: 0.7449 - lr: 6.2500e-05
# Epoch 102/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1449 - accuracy: 0.9570
# Epoch 102: val_accuracy did not improve from 0.74490
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1477 - accuracy: 0.9592 - val_loss: 0.8001 - val_accuracy: 0.7245 - lr: 6.2500e-05
# Epoch 103/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1598 - accuracy: 0.9570
# Epoch 103: val_accuracy did not improve from 0.74490
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1503 - accuracy: 0.9579 - val_loss: 0.9031 - val_accuracy: 0.7041 - lr: 6.2500e-05
# Epoch 104/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1514 - accuracy: 0.9648
# Epoch 104: val_accuracy did not improve from 0.74490
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1414 - accuracy: 0.9579 - val_loss: 0.9068 - val_accuracy: 0.7041 - lr: 6.2500e-05
# Epoch 105/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1473 - accuracy: 0.9531
# Epoch 105: val_accuracy did not improve from 0.74490
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1442 - accuracy: 0.9528 - val_loss: 0.7629 - val_accuracy: 0.7143 - lr: 6.2500e-05
# Epoch 106/150
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1131 - accuracy: 0.9727
# Epoch 106: val_accuracy did not improve from 0.74490
# Restoring model weights from the end of the best epoch: 86.
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1503 - accuracy: 0.9528 - val_loss: 0.7319 - val_accuracy: 0.7449 - lr: 6.2500e-05
# Epoch 106: early stopping
# ✅ Training completed in 0.00 hours

# %% [markdown]
# ## 9. 📊 Evaluation

# %%
print("\n📊 Evaluating model...")

# Load best model
landmark_model = load_model(MODEL_PATH + 'landmark_model_best.h5')

# Evaluate on test set
test_loss, test_acc = landmark_model.evaluate(X_test_landmarks, y_test_onehot, verbose=0)
print(f"🎯 Test Accuracy: {test_acc:.4f}")
print(f"📉 Test Loss: {test_loss:.4f}")

# Detailed predictions
y_pred = np.argmax(landmark_model.predict(X_test_landmarks, batch_size=BATCH_SIZE), axis=1)
y_true = np.argmax(y_test_onehot, axis=1)

# Classification report
print("\n📈 Classification Report:")
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# 📊 Evaluating model...
# 🎯 Test Accuracy: 0.7347
# 📉 Test Loss: 1.2804
# 1/1 [==============================] - 0s 66ms/step
#
# 📈 Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.40      0.86      0.55        14
#     contempt       0.00      0.00      0.00         6
#    disgusted       0.77      1.00      0.87        17
#         fear       0.00      0.00      0.00         7
#        happy       0.88      1.00      0.93        21
#          sad       1.00      0.12      0.22         8
#    surprised       1.00      0.84      0.91        25
#
#     accuracy                           0.73        98
#    macro avg       0.58      0.55      0.50        98
# weighted avg       0.72      0.73      0.68        98
# c:\Users\fitra\miniconda3\envs\multimodal-emotion\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\fitra\miniconda3\envs\multimodal-emotion\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\fitra\miniconda3\envs\multimodal-emotion\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## 10. 📊 Visualization

# %%
print("📊 Creating visualizations...")

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens',
           xticklabels=target_names, yticklabels=target_names)
plt.title(f'Landmark Model Confusion Matrix (Test Acc: {test_acc:.4f})')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.savefig(MODEL_PATH + 'landmark_confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()

# Training history
if 'landmark_history' in locals():
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    # Accuracy plot
    axes[0].plot(landmark_history.history['accuracy'], label='Training Accuracy')
    axes[0].plot(landmark_history.history['val_accuracy'], label='Validation Accuracy')
    axes[0].set_title('Landmark Model Accuracy')
    axes[0].set_ylabel('Accuracy')
    axes[0].set_xlabel('Epoch')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)
    
    # Loss plot
    axes[1].plot(landmark_history.history['loss'], label='Training Loss')
    axes[1].plot(landmark_history.history['val_loss'], label='Validation Loss')
    axes[1].set_title('Landmark Model Loss')
    axes[1].set_ylabel('Loss')
    axes[1].set_xlabel('Epoch')
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(MODEL_PATH + 'landmark_training_history.png', dpi=300, bbox_inches='tight')
    plt.show()
# Out:
# 📊 Creating visualizations...

# %% [markdown]
# ## 11. 💾 Save Results

# %%
print("💾 Saving results...")

# Save training info
training_info = {
    'model_type': 'Landmark',
    'gpu_used': gpu_available,
    'num_gpus': num_gpus,
    'batch_size': BATCH_SIZE,
    'epochs_trained': len(landmark_history.history['accuracy']) if 'landmark_history' in locals() else 0,
    'test_accuracy': test_acc,
    'test_loss': test_loss,
    'total_parameters': landmark_model.count_params(),
    'training_time_hours': training_time/3600 if 'training_time' in locals() else 0,
    'device_info': f"AMD GPU ({num_gpus} device(s))" if gpu_available else "CPU"
}

with open(MODEL_PATH + 'landmark_training_info.pkl', 'wb') as f:
    pickle.dump(training_info, f)
# Out:
# 💾 Saving results...

# %% [markdown]
# ## 12. 📝 Summary

# %%
print("\n" + "=" * 60)
print("🎉 LANDMARK TRAINING COMPLETED!")
print("=" * 60)
print(f"📊 Final Test Accuracy: {test_acc:.4f}")
print(f"🎮 Device Used: {'AMD GPU' if gpu_available else 'CPU'}")
print(f"⏱️ Training Time: {training_time/3600:.2f} hours" if 'training_time' in locals() else "N/A")
print(f"💾 Model saved to: {MODEL_PATH}landmark_model_best.h5")
print(f"📈 Visualizations saved to: {MODEL_PATH}")
print("\n🚀 Ready for next step: Late Fusion!")
print("=" * 60)
# Out:
# ============================================================
# 🎉 LANDMARK TRAINING COMPLETED!
# ============================================================
# 📊 Final Test Accuracy: 0.7347
# 🎮 Device Used: AMD GPU
# ⏱️ Training Time: 0.00 hours
# 💾 Model saved to: D:/research/2025_iris_taufik/MultimodalEmoLearn/models/landmark_model_best.h5
# 📈 Visualizations saved to: D:/research/2025_iris_taufik/MultimodalEmoLearn/models/
#
# 🚀 Ready for next step: Late Fusion!
# ============================================================
